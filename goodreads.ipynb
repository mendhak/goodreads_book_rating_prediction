# %% [markdown]
# Let's begin. goodreads_library_export.csv contains the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8')

# %%
df = pd.read_csv('goodreads_library_export.csv')
print("Shape of the dataset:", df.shape)
print("Columns in the dataset:", df.columns.tolist())
print("Dataset info:")
df.info()
# Out:
# Shape of the dataset: (2610, 24)
# Columns in the dataset: ['Book Id', 'Title', 'Author', 'Author l-f', 'Additional Authors', 'ISBN', 'ISBN13', 'My Rating', 'Average Rating', 'Publisher', 'Binding', 'Number of Pages', 'Year Published', 'Original Publication Year', 'Date Read', 'Date Added', 'Bookshelves', 'Bookshelves with positions', 'Exclusive Shelf', 'My Review', 'Spoiler', 'Private Notes', 'Read Count', 'Owned Copies']
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2610 entries, 0 to 2609
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Book Id                     2610 non-null   int64
#  1   Title                       2610 non-null   object
#  2   Author                      2610 non-null   object
#  3   Author l-f                  2610 non-null   object
#  4   Additional Authors          815 non-null    object
#  5   ISBN                        2610 non-null   object
#  6   ISBN13                      2610 non-null   object
#  7   My Rating                   2610 non-null   int64
#  8   Average Rating              2610 non-null   float64
#  9   Publisher                   2531 non-null   object
#  10  Binding                     2586 non-null   object
#  11  Number of Pages             2541 non-null   float64
#  12  Year Published              2547 non-null   float64
#  13  Original Publication Year   2507 non-null   float64
#  14  Date Read                   1384 non-null   object
#  15  Date Added                  2610 non-null   object
#  16  Bookshelves                 1924 non-null   object
#  17  Bookshelves with positions  1924 non-null   object
#  18  Exclusive Shelf             2610 non-null   object
#  19  My Review                   354 non-null    object
#  20  Spoiler                     33 non-null     object
#  21  Private Notes               1 non-null      object
#  22  Read Count                  2610 non-null   int64
#  23  Owned Copies                2610 non-null   int64
# dtypes: float64(4), int64(4), object(16)
# memory usage: 489.5+ KB

# %%
# Inspecting the dataset 
print("First few rows")
display(df.head())
# Out:
# First few rows
#     Book Id                                              Title  \
# 0    893590                       Diamond Dogs, Turquoise Days
# 1   8444621  Through the Language Glass: Why the World Look...
# 2  56769571                                   Damascus Station
# 3   1455439  Nightside the Long Sun (The Book of the Long S...
# 4  29397486                                           Conclave
#
#               Author          Author l-f Additional Authors           ISBN  \
# 0  Alastair Reynolds  Reynolds, Alastair                NaN  ="0575075163"
# 1      Guy Deutscher      Deutscher, Guy                NaN  ="080508195X"
# 2    David McCloskey    McCloskey, David                NaN  ="0393881040"
# 3         Gene Wolfe         Wolfe, Gene                NaN  ="0812516257"
# 4    Robert   Harris      Harris, Robert                NaN            =""
#
#              ISBN13  My Rating  Average Rating               Publisher  \
# 0  ="9780575075160"          0            4.00                Gollancz
# 1  ="9780805081954"          3            3.91      Metropolitan Books
# 2  ="9780393881042"          2            4.17  W. W. Norton & Company
# 3  ="9780812516258"          1            4.08               Tor Books
# 4               =""          0            4.11     Cornerstone Digital
#
#                  Binding  Number of Pages  Year Published  \
# 0              Paperback            231.0          2003.0
# 1              Hardcover            304.0          2010.0
# 2              Hardcover            432.0          2021.0
# 3  Mass Market Paperback            333.0          1993.0
# 4                  ebook            288.0          2016.0
#
#    Original Publication Year   Date Read  Date Added  \
# 0                     2001.0         NaN  2025/05/02
# 1                     2010.0  2025/08/05  2025/02/19
# 2                     2021.0  2025/07/29  2025/03/09
# 3                     1993.0  2025/07/24  2013/07/06
# 4                     2016.0         NaN  2025/07/22
#
#                                    Bookshelves  \
# 0  currently-reading, science-fiction, fiction
# 1                                          NaN
# 2                                          NaN
# 3        fiction, pretentious, science-fiction
# 4                                      to-read
#
#                           Bookshelves with positions    Exclusive Shelf  \
# 0  currently-reading (#1), science-fiction (#297)...  currently-reading
# 1                                                NaN               read
# 2                                                NaN               read
# 3  fiction (#319), pretentious (#5), science-fict...               read
# 4                                     to-read (#281)            to-read
#
#                                            My Review Spoiler Private Notes  \
# 0                                                NaN     NaN           NaN
# 1                                                NaN     NaN           NaN
# 2  interesting modern espionage thriller, it was ...     NaN           NaN
# 3  The cranial fissure that appeared over the cou...     NaN           NaN
# 4                                                NaN     NaN           NaN
#
#    Read Count  Owned Copies
# 0           1             0
# 1           1             0
# 2           1             0
# 3           1             0
# 4           0             0

# %%
print("Missing values")
display(df.isnull().sum())
# Out:
# Missing values
# Book Id                          0
# Title                            0
# Author                           0
# Author l-f                       0
# Additional Authors            1795
# ISBN                             0
# ISBN13                           0
# My Rating                        0
# Average Rating                   0
# Publisher                       79
# Binding                         24
# Number of Pages                 69
# Year Published                  63
# Original Publication Year      103
# Date Read                     1226
# Date Added                       0
# Bookshelves                    686
# Bookshelves with positions     686
# Exclusive Shelf                  0
# My Review                     2256
# Spoiler                       2577
# Private Notes                 2609
# Read Count                       0
# Owned Copies                     0
# dtype: int64

# %%
print("\nBasic statistics:")
display(df.describe())
# Out:
# Basic statistics:
#             Book Id    My Rating  Average Rating  Number of Pages  \
# count  2.610000e+03  2610.000000     2610.000000      2541.000000
# mean   2.159522e+07     1.827203        4.115195       328.272334
# std    3.217598e+07     1.553575        0.386373       285.165621
# min    3.000000e+00     0.000000        0.000000         0.000000
# 25%    8.248418e+05     0.000000        3.950000       197.000000
# 50%    1.220052e+07     2.000000        4.170000       257.000000
# 75%    3.012078e+07     3.000000        4.350000       400.000000
# max    2.338000e+08     5.000000        5.000000      9707.000000
#
#        Year Published  Original Publication Year   Read Count  Owned Copies
# count     2547.000000                2507.000000  2610.000000        2610.0
# mean      2009.906164                1995.036298     0.915326           0.0
# std          8.913977                 119.901499     0.352556           0.0
# min       1925.000000               -1200.000000     0.000000           0.0
# 25%       2005.000000                2000.000000     1.000000           0.0
# 50%       2011.000000                2009.000000     1.000000           0.0
# 75%       2016.000000                2015.000000     1.000000           0.0
# max       2026.000000                2026.000000     4.000000           0.0

# %%
print("\nUnique values in key columns:")
for col in ['Exclusive Shelf', 'My Rating', 'Bookshelves']:
    print(f"\n{col}:")
    display(df[col].value_counts())
# Out:
# Unique values in key columns:
#
# Exclusive Shelf:
# Exclusive Shelf
# read                 2317
# to-read               280
# abandoned              12
# currently-reading       1
# Name: count, dtype: int64
# My Rating:
# My Rating
# 0    869
# 3    653
# 2    400
# 4    362
# 1    267
# 5     59
# Name: count, dtype: int64
# Bookshelves:
# Bookshelves
# manga                                   702
# to-read                                 280
# science-fiction                         224
# fantasy                                 224
# fiction                                 166
#                                        ...
# abandoned, rubbish, fiction               1
# popular-science, science-fiction          1
# fiction, abandoned                        1
# paranormal, fiction                       1
# fiction, fantasy, historical-fiction      1
# Name: count, Length: 132, dtype: int64

# %%
# read books only

read_books_df = df[df['Exclusive Shelf'] == 'read']
print("\nShape of read books dataset:", read_books_df.shape)
# Out:
# Shape of read books dataset: (2317, 24)

# %% [markdown]
# Rating Distribution

# %%
# Rating distribution visualization
plt.figure(figsize=(10, 6))
sns.countplot(data=read_books_df, x='My Rating')
plt.title('Distribution of Ratings for Read Books')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# Average rating statistics
read_ratings = read_books_df[read_books_df['My Rating'] > 0]
print(f"\nTotal read books: {len(read_books_df)}")
print(f"Books with ratings: {len(read_ratings)}")
print("\nRating statistics:")
display(read_ratings['My Rating'].describe())

# Genre analysis from Bookshelves for read books
genres = read_books_df[read_books_df['Bookshelves'].notna()]['Bookshelves'].str.split(', ', expand=True)
genre_counts = pd.Series([x for l in genres.values.flatten() if isinstance(l, str) for x in l.split(', ')]).value_counts()

print("\nMost common genres in read books:")
display(genre_counts.head(10))

# Genre ratings
def get_genre_ratings(df):
    genre_ratings = []
    for idx, row in df.iterrows():
        if pd.notna(row['Bookshelves']) and row['My Rating'] > 0:
            genres = row['Bookshelves'].split(', ')
            for genre in genres:
                genre_ratings.append({'genre': genre, 'rating': row['My Rating']})
    return pd.DataFrame(genre_ratings)

genre_ratings = get_genre_ratings(read_books_df)
genre_avg = genre_ratings.groupby('genre').agg({
    'rating': ['mean', 'count']
}).sort_values(('rating', 'count'), ascending=False)
genre_avg = genre_avg[genre_avg['rating']['count'] >= 10]  # Only genres with at least 10 books

print("\nAverage ratings by genre (minimum 10 books):")
display(genre_avg)
# Out:
# Total read books: 2317
# Books with ratings: 1728
#
# Rating statistics:
# count    1728.000000
# mean        2.750579
# std         1.052611
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: My Rating, dtype: float64
# Most common genres in read books:
# manga                 702
# fantasy               319
# fiction               317
# science-fiction       292
# mystery                67
# historical-fiction     64
# popular-science        39
# light-novel            27
# rubbish                23
# suspense               20
# Name: count, dtype: int64
# Average ratings by genre (minimum 10 books):
#                       rating
#                         mean count
# genre
# manga               2.853933   356
# fantasy             2.769231   312
# fiction             2.392283   311
# science-fiction     3.121528   288
# historical-fiction  2.639344    61
# mystery             2.897959    49
# popular-science     3.179487    39
# light-novel         2.961538    26
# rubbish             1.130435    23
# cozy                3.166667    18
# paranormal          2.562500    16
# suspense            3.250000    16
# non-fiction         3.083333    12
# wholesome           3.500000    10

# %%
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer

mlb = MultiLabelBinarizer()
book_genres = read_books_df['Bookshelves'].fillna('').str.split(', ')
genre_features = pd.DataFrame(mlb.fit_transform(book_genres), columns=mlb.classes_, index=read_books_df.index)

# Create feature matrix and handle authors
features = pd.DataFrame(index=read_books_df.index)
author_encoder = LabelEncoder()
encoded_authors = author_encoder.fit_transform(read_books_df['Author'].fillna('Unknown Author'))
features['Author'] = encoded_authors

features['Year Published'] = read_books_df['Year Published']
features['Number of Pages'] = read_books_df['Number of Pages']

features = pd.concat([features, genre_features], axis=1)

features = features.fillna({
    'Number of Pages': 0,
    'Year Published': 2000
})


print("Number of NaN values:", features['Author'].isna().sum().sum())
print("Feature matrix shape:", features.shape)
print("\nFeature columns:", features.columns[:10].tolist(), "...")

display(features)
# Out:
# Number of NaN values: 0
# Feature matrix shape: (2317, 26)
#
# Feature columns: ['Author', 'Year Published', 'Number of Pages', '', 'confusing', 'cozy', 'fantasy', 'fiction', 'historical-fiction', 'history'] ...
#       Author  Year Published  Number of Pages     confusing  cozy  fantasy  \
# 1        202          2010.0            304.0  1          0     0        0
# 2        133          2021.0            432.0  1          0     0        0
# 3        194          1993.0            333.0  0          0     0        0
# 5        236          2021.0            263.0  0          0     0        0
# 6        574          2024.0            480.0  0          0     0        0
# ...      ...             ...              ... ..        ...   ...      ...
# 2605     560          1997.0            498.0  0          0     0        1
# 2606     560          2007.0            610.0  0          0     0        1
# 2607     563          2005.0            128.0  0          0     0        1
# 2608     327          2003.0            654.0  0          0     0        0
# 2609     327          2003.0            496.0  0          0     0        0
#
#       fiction  historical-fiction  history  horror  isekai  light-novel  \
# 1           0                   0        0       0       0            0
# 2           0                   0        0       0       0            0
# 3           1                   0        0       0       0            0
# 5           1                   0        0       1       0            0
# 6           0                   0        0       0       0            1
# ...       ...                 ...      ...     ...     ...          ...
# 2605        0                   0        0       0       0            0
# 2606        0                   0        0       0       0            0
# 2607        0                   0        0       0       0            0
# 2608        0                   0        0       0       0            0
# 2609        0                   0        0       0       0            0
#
#       manga  mystery  non-fiction  paranormal  popular-science  pretentious  \
# 1         0        0            0           0                0            0
# 2         0        0            0           0                0            0
# 3         0        0            0           0                0            1
# 5         0        0            0           1                0            0
# 6         0        0            0           0                0            0
# ...     ...      ...          ...         ...              ...          ...
# 2605      0        0            0           0                0            0
# 2606      0        0            0           0                0            0
# 2607      0        0            0           0                0            0
# 2608      0        0            0           0                0            0
# 2609      0        0            0           0                0            0
#
#       rubbish  science-fiction  suspense  travelogue  visual-novel  wholesome  \
# 1           0                0         0           0             0          0
# 2           0                0         0           0             0          0
# 3           0                1         0           0             0          0
# 5           0                1         0           0             0          0
# 6           0                0         0           0             0          0
# ...       ...              ...       ...         ...           ...        ...
# 2605        0                0         0           0             0          0
# 2606        0                0         0           0             0          0
# 2607        0                0         0           0             0          0
# 2608        0                1         0           0             0          0
# 2609        0                1         0           0             0          0
#
#       young-adult
# 1               0
# 2               0
# 3               0
# 5               0
# 6               0
# ...           ...
# 2605            0
# 2606            0
# 2607            0
# 2608            0
# 2609            0
#
# [2317 rows x 26 columns]

# %%
# Prepare training data

training_X = features.copy()  # This is the feature set, the 'input' so to speak. Could add more kinds of features later like sentiment?
training_Y = read_books_df['My Rating']  # this is the target to predict

# Remove where rating = 0, or only include where books have ratings
training_X = training_X[training_Y > 0]
training_Y = training_Y[training_Y > 0]

print("Training data shape:", training_X.shape)
print("Number of rated books:", len(training_Y))
# Out:
# Training data shape: (1728, 26)
# Number of rated books: 1728

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

X_train, X_test, Y_train, Y_text = train_test_split(training_X, training_Y, test_size=0.2, random_state=23498234)

# %%
random_forest_model = RandomForestRegressor(n_estimators=100, random_state=128383)

random_forest_model.fit(X_train, Y_train)

Y_predicted = random_forest_model.predict(X_test)

mse = mean_squared_error(Y_text, Y_predicted)
mae = mean_absolute_error(Y_text, Y_predicted)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)

plt.figure(figsize=(10, 6))
plt.scatter(Y_text, Y_predicted, alpha=0.5)
plt.plot([0, 5], [0, 5], 'r--')  # Perfect prediction line
plt.xlabel('Actual Ratings')
plt.ylabel('Predicted Ratings')
plt.title('Predicted vs Actual Ratings')
plt.show()

# Distribution of prediction errors
errors = Y_text - Y_predicted
plt.figure(figsize=(10, 6))
plt.hist(errors, bins=20)
plt.title('Distribution of Prediction Errors')
plt.xlabel('Prediction Error')
plt.ylabel('Count')
plt.show()
# Out:
# Mean Squared Error: 0.8803814363776367
# Mean Absolute Error: 0.729168237911735

# %%
# Feature importance - which were most influential?
feature_importance = pd.DataFrame({
    'feature': training_X.columns,
    'importance': random_forest_model.feature_importances_
})
feature_importance = feature_importance.sort_values('importance', ascending=False)
print("\nTop 10 most important features:")
display(feature_importance.head(10))
# Out:
# Top 10 most important features:
#             feature  importance
# 2   Number of Pages    0.309037
# 0            Author    0.292821
# 1    Year Published    0.205235
# 19          rubbish    0.035275
# 20  science-fiction    0.028622
# 7           fiction    0.027266
# 13            manga    0.024241
# 6           fantasy    0.016274
# 3                      0.011920
# 17  popular-science    0.010506

# %%
# Get unread books (to-read shelf)
to_read = df[df['Exclusive Shelf'] == 'to-read']

to_read.loc[:, 'Bookshelves'] = to_read['Bookshelves'].str.replace('to-read, ', '').str.replace('to-read', '')

# Prepare features for unread books
to_read_features = pd.DataFrame()

all_authors = pd.concat([read_books_df['Author'], to_read['Author']]).unique()
author_encoder.fit(all_authors)

to_read_features['Author'] = author_encoder.transform(to_read['Author'].fillna('Unknown Author'))
to_read_features['Year Published'] = to_read['Year Published']
to_read_features['Number of Pages'] = to_read['Number of Pages']

# Get genres for unread books
unread_genres = to_read['Bookshelves'].fillna('').str.split(', ')
unread_genre_features = pd.DataFrame(
    mlb.transform(unread_genres), 
    columns=mlb.classes_,
    index=to_read.index
)

# Combine features
to_read_features = pd.concat([to_read_features, unread_genre_features], axis=1)
to_read_features = to_read_features.fillna({
    'Number of Pages': 0,
    'Year Published': 2000
})

# %%
# Get unread books (to-read shelf)
to_read = df[df['Exclusive Shelf'] == 'to-read'].copy()
to_read.loc[:, 'Bookshelves'] = to_read['Bookshelves'].str.replace('to-read, ', '').str.replace('to-read', '')

to_read_features = pd.DataFrame(index=to_read.index)

all_authors = pd.concat([read_books_df['Author'], to_read['Author']]).unique()
author_encoder.fit(all_authors)
to_read_features['Author'] = author_encoder.transform(to_read['Author'].fillna('Unknown Author'))

to_read_features['Year Published'] = to_read['Year Published']
to_read_features['Number of Pages'] = to_read['Number of Pages']

# Get genres - make sure to use the same index
unread_genres = to_read['Bookshelves'].fillna('').str.split(', ')
unread_genre_features = pd.DataFrame(
    mlb.transform(unread_genres), 
    columns=mlb.classes_,
    index=to_read.index
)

to_read_features = pd.concat([to_read_features, unread_genre_features], axis=1)

# Fill missing values
to_read_features = to_read_features.fillna({
    'Number of Pages': 0,
    'Year Published': 2000
})

# print("Shapes after processing:")
# print("to_read shape:", to_read.shape)
# print("to_read_features shape:", to_read_features.shape)

# Make predictions
predicted_ratings = random_forest_model.predict(to_read_features)
# print("predicted_ratings shape:", predicted_ratings.shape)



human_readable_predictions =  to_read[['Title', 'Author', 'Bookshelves']].copy()
human_readable_predictions['Predicted Rating'] = predicted_ratings

human_readable_predictions['Rating Sentence'] = human_readable_predictions['Predicted Rating'].apply(
    lambda x: "You might like it" if x >= 2.8 else ("It might be okay" if x >= 2.0 else "You probably won't like it")
)

human_readable_predictions = human_readable_predictions.sort_values('Predicted Rating', ascending=False)
print("\nTop 10 recommended books:")
display(human_readable_predictions.head(100))

for idx, prediction in human_readable_predictions.iterrows():
    print(f"{prediction['Title']} by {prediction['Author']}: {prediction['Rating Sentence']} (Predicted Rating: {prediction['Predicted Rating']:.2f})")
# Out:
# Top 10 recommended books:
#                                                   Title                Author  \
# 1778         The Rings of Haven (The Frontiers Saga #2)             Ryk Brown
# 255                Off to Be the Wizard (Magic 2.0, #1)           Scott Meyer
# 1246            Knots and Crosses (Inspector Rebus, #1)            Ian Rankin
# 875   Higurashi When They Cry: Beyond Midnight Arc, ...            Ryukishi07
# 245                The Metamorphosis of Prime Intellect        Roger Williams
# ...                                                 ...                   ...
# 684   The Calculating Stars (Lady Astronaut Universe...  Mary Robinette Kowal
# 237    A Mouthful of Dust (The Singing Hills Cycle, #6)               Nghi Vo
# 713    She Who Became the Sun (The Radiant Emperor, #1)   Shelley Parker-Chan
# 1070        Elysium Fire (Prefect Dreyfus Emergency #2)     Alastair Reynolds
# 1154          Daughter of the Forest  (Sevenwaters, #1)      Juliet Marillier
#
#      Bookshelves  Predicted Rating    Rating Sentence
# 1778                          3.76  You might like it
# 255                           3.66  You might like it
# 1246                          3.59  You might like it
# 875                           3.58  You might like it
# 245                           3.54  You might like it
# ...          ...               ...                ...
# 684                           2.83  You might like it
# 237                           2.83  You might like it
# 713                           2.83  You might like it
# 1070                          2.82  You might like it
# 1154                          2.82  You might like it
#
# [100 rows x 5 columns]
# The Rings of Haven (The Frontiers Saga #2) by Ryk Brown: You might like it (Predicted Rating: 3.76)
# Off to Be the Wizard (Magic 2.0, #1) by Scott Meyer: You might like it (Predicted Rating: 3.66)
# Knots and Crosses (Inspector Rebus, #1) by Ian Rankin: You might like it (Predicted Rating: 3.59)
# Higurashi When They Cry: Beyond Midnight Arc, Vol. 1 by Ryukishi07: You might like it (Predicted Rating: 3.58)
# The Metamorphosis of Prime Intellect by Roger Williams: You might like it (Predicted Rating: 3.54)
# The Relentless Moon (Lady Astronaut Universe, #3) by Mary Robinette Kowal: You might like it (Predicted Rating: 3.53)
# Zones of Thought: A Fire Upon the Deep / A Deepness in the Sky by Vernor Vinge: You might like it (Predicted Rating: 3.50)
# Forge of Darkness (The Kharkanas Trilogy, #1) by Steven Erikson: You might like it (Predicted Rating: 3.47)
# The Gene: An Intimate History by Siddhartha Mukherjee: You might like it (Predicted Rating: 3.43)
# A Stranger in Olondria by Sofia Samatar: You might like it (Predicted Rating: 3.42)
# File No. 113 (Monsieur Lecoq #3) by Émile Gaboriau: You might like it (Predicted Rating: 3.41)
# The Book That Wouldn’t Burn (The Library Trilogy, #1) by Mark  Lawrence: You might like it (Predicted Rating: 3.39)
# Mogworld by Yahtzee Croshaw: You might like it (Predicted Rating: 3.39)
# The Decisive Moment: How The Brain Makes Up Its Mind by lehrer-jonah: You might like it (Predicted Rating: 3.38)
# Implied Spaces by Walter Jon Williams: You might like it (Predicted Rating: 3.36)
# The Secret (The Secret, #1) by Rhonda Byrne: You might like it (Predicted Rating: 3.36)
# A Man Called Ove by Fredrik Backman: You might like it (Predicted Rating: 3.32)
# Pandora's Star (Commonwealth Saga #1) by Peter F. Hamilton: You might like it (Predicted Rating: 3.28)
# The Reincarnated Giant: An Anthology of Twenty-First-Century Chinese Science Fiction (Weatherhead Books on Asia) by Mingwei Song: You might like it (Predicted Rating: 3.25)
# The Kingdoms by Natasha Pulley: You might like it (Predicted Rating: 3.25)
# Tau Zero by Poul Anderson: You might like it (Predicted Rating: 3.24)
# Blood River: A Journey to Africa’s Broken Heart by Tim Butcher: You might like it (Predicted Rating: 3.24)
# Sorcerer to the Crown (Sorcerer Royal, #1) by Zen Cho: You might like it (Predicted Rating: 3.24)
# Blue Remembered Earth (Poseidon's Children, #1) by Alastair Reynolds: You might like it (Predicted Rating: 3.23)
# Machine City (Detective Barnes, #2) by Scott J. Holliday: You might like it (Predicted Rating: 3.23)
# The Mist by Stephen        King: You might like it (Predicted Rating: 3.22)
# The Institute by Stephen        King: You might like it (Predicted Rating: 3.21)
# East of Eden by John Steinbeck: You might like it (Predicted Rating: 3.21)
# The Innocence of Father Brown (Father Brown, #1) by G.K. Chesterton: You might like it (Predicted Rating: 3.20)
# Spin (Spin, #1) by Robert Charles Wilson: You might like it (Predicted Rating: 3.20)
# The Quest (Ancient Egypt, #4) by Wilbur Smith: You might like it (Predicted Rating: 3.18)
# Titus Groan (Gormenghast, #1) by Mervyn Peake: You might like it (Predicted Rating: 3.17)
# The Outsider by Stephen        King: You might like it (Predicted Rating: 3.17)
# The Ministry for the Future by Kim Stanley Robinson: You might like it (Predicted Rating: 3.17)
# Odinn's Child (Viking, #1) by Tim Severin: You might like it (Predicted Rating: 3.16)
# The Long Walk by Richard  Bachman: You might like it (Predicted Rating: 3.15)
# Spinning Silver by Naomi Novik: You might like it (Predicted Rating: 3.15)
# Mexican Gothic by Silvia Moreno-Garcia: You might like it (Predicted Rating: 3.15)
# 極主夫道 1 [Gokushufudō 1] by Kousuke Oono: You might like it (Predicted Rating: 3.14)
# The Road to Reality: A Complete Guide to the Laws of the Universe by Roger Penrose: You might like it (Predicted Rating: 3.13)
# The Black Echo (Harry Bosch, #1; Harry Bosch Universe, #1) by Michael    Connelly: You might like it (Predicted Rating: 3.11)
# Satan in St Mary's (Hugh Corbett, #1) by Paul  Doherty: You might like it (Predicted Rating: 3.10)
# The City We Became (Great Cities, #1) by N.K. Jemisin: You might like it (Predicted Rating: 3.07)
# Black Sun (Between Earth and Sky, #1) by Rebecca Roanhorse: You might like it (Predicted Rating: 3.07)
# The Cretaceous Past by Liu Cixin: You might like it (Predicted Rating: 3.06)
# The Poppy War (The Poppy War, #1) by R.F. Kuang: You might like it (Predicted Rating: 3.06)
# The Stone Wētā by Octavia Cade: You might like it (Predicted Rating: 3.06)
# Mistress of the Art of Death (Mistress of the Art of Death, #1) by Ariana Franklin: You might like it (Predicted Rating: 3.05)
# Shadow of a Dark Queen (The Serpentwar Saga, #1) by Raymond E. Feist: You might like it (Predicted Rating: 3.05)
# Revenger (Revenger #1) by Alastair Reynolds: You might like it (Predicted Rating: 3.04)
# Voice of the Fire by Alan             Moore: You might like it (Predicted Rating: 3.04)
# How High We Go in the Dark by Sequoia Nagamatsu: You might like it (Predicted Rating: 3.02)
# Whose Body?  (Lord Peter Wimsey, #1) by Dorothy L. Sayers: You might like it (Predicted Rating: 3.01)
# The Goblin Emperor (The Chronicles of Osreth, #1) by Katherine Addison: You might like it (Predicted Rating: 3.01)
# Odyssey One (Odyssey One, #1) by Evan Currie: You might like it (Predicted Rating: 3.00)
# Middlegame (Alchemical Journeys, #1) by Seanan McGuire: You might like it (Predicted Rating: 3.00)
# The Fountains of Paradise by Arthur C. Clarke: You might like it (Predicted Rating: 3.00)
# The Freeze-Frame Revolution by Peter Watts: You might like it (Predicted Rating: 2.99)
# The Wandering Inn (The Wandering Inn, #1) by Pirateaba: You might like it (Predicted Rating: 2.99)
# The Devil and the Dark Water by Stuart Turton: You might like it (Predicted Rating: 2.98)
# March Upcountry (Empire of Man, #1) by David Weber: You might like it (Predicted Rating: 2.98)
# 転生したらスライムだった件 1 [Tensei shitara Slime Datta Ken [Light Novel] 1] (That Time I Got Reincarnated as a Slime [Light Novel], #1) by Fuse: You might like it (Predicted Rating: 2.97)
# A Plague on Both Your Houses (Matthew Bartholomew, #1) by Susanna Gregory: You might like it (Predicted Rating: 2.96)
# How It Unfolds (The Far Reaches, #1) by James S.A. Corey: You might like it (Predicted Rating: 2.95)
# Lexicon by Max Barry: You might like it (Predicted Rating: 2.95)
# Rosewater (The Wormwood Trilogy, #1) by Tade Thompson: You might like it (Predicted Rating: 2.95)
# Dreamweaver's Dilemma (Vorkosigan Saga, #9.1) by Lois McMaster Bujold: You might like it (Predicted Rating: 2.95)
# The Novice's Tale (Sister Frevisse, #1) by Margaret Frazer: You might like it (Predicted Rating: 2.94)
# In the Beginning Was the Sea (Pushkin Collection) by Tomás González: You might like it (Predicted Rating: 2.94)
# In the Company of Cheerful Ladies (No. 1 Ladies' Detective Agency, #6) by Alexander McCall Smith: You might like it (Predicted Rating: 2.94)
# City of Stairs (The Divine Cities, #1) by Robert Jackson Bennett: You might like it (Predicted Rating: 2.94)
# Crocodile on the Sandbank (Amelia Peabody, #1) by Elizabeth Peters: You might like it (Predicted Rating: 2.94)
# The Sparrow (The Sparrow, #1) by Mary Doria Russell: You might like it (Predicted Rating: 2.93)
# Sapiens: A Brief History of Humankind by Yuval Noah Harari: You might like it (Predicted Rating: 2.92)
# The Blessing Way (Leaphorn & Chee, #1) by Tony Hillerman: You might like it (Predicted Rating: 2.92)
# The Genesis Quest by Donald Moffitt: You might like it (Predicted Rating: 2.91)
# The Toilers of the Sea by Victor Hugo: You might like it (Predicted Rating: 2.91)
# The Hidden Girl and Other Stories by Ken Liu: You might like it (Predicted Rating: 2.91)
# Pyrebound by Brayton Cole: You might like it (Predicted Rating: 2.91)
# Time (Manifold #1) by Stephen Baxter: You might like it (Predicted Rating: 2.91)
# The Thorn of Emberlain (Gentleman Bastard, #4) by Scott Lynch: You might like it (Predicted Rating: 2.90)
# The Rose Rent (Chronicles of Brother Cadfael, #13) by Ellis Peters: You might like it (Predicted Rating: 2.89)
# Seirei Gensouki: Spirit Chronicles Volume 1 by Yuri Kitayama: You might like it (Predicted Rating: 2.89)
# How Forests Think: Toward an Anthropology Beyond the Human by Eduardo Kohn: You might like it (Predicted Rating: 2.89)
# How a Realist Hero Rebuilt the Kingdom, Volume 1 by Dojyomaru: You might like it (Predicted Rating: 2.87)
# The Golem and the Jinni (The Golem and the Jinni, #1) by Helene Wecker: You might like it (Predicted Rating: 2.87)
# Prince of the Blood (Krondor's Sons, #1) by Raymond E. Feist: You might like it (Predicted Rating: 2.87)
# Metro 2033 (Metro, #1) by Dmitry Glukhovsky: You might like it (Predicted Rating: 2.87)
# Tales from Earthsea (Earthsea Cycle, #5) by Ursula K. Le Guin: You might like it (Predicted Rating: 2.86)
# The God is Not Willing (Witness, #1) by Steven Erikson: You might like it (Predicted Rating: 2.86)
# The Strength of the Few (Hierarchy, #2) by James  Islington: You might like it (Predicted Rating: 2.86)
# Dragonflight (Dragonriders of Pern, #1) by Anne McCaffrey: You might like it (Predicted Rating: 2.85)
# The Silver Pigs (Marcus Didius Falco, #1) by Lindsey Davis: You might like it (Predicted Rating: 2.85)
# The Hallowed Hunt (World of the Five Gods, #3) by Lois McMaster Bujold: You might like it (Predicted Rating: 2.84)
# The Captain (The Last Horizon, #1) by Will Wight: You might like it (Predicted Rating: 2.84)
# The Calculating Stars (Lady Astronaut Universe, #1) by Mary Robinette Kowal: You might like it (Predicted Rating: 2.83)
# A Mouthful of Dust (The Singing Hills Cycle, #6) by Nghi Vo: You might like it (Predicted Rating: 2.83)
# She Who Became the Sun (The Radiant Emperor, #1) by Shelley Parker-Chan: You might like it (Predicted Rating: 2.83)
# Elysium Fire (Prefect Dreyfus Emergency #2) by Alastair Reynolds: You might like it (Predicted Rating: 2.82)
# Daughter of the Forest  (Sevenwaters, #1) by Juliet Marillier: You might like it (Predicted Rating: 2.82)
# Imperium (Cicero, #1) by Robert   Harris: You might like it (Predicted Rating: 2.82)
# Jade City (The Green Bone Saga, #1) by Fonda Lee: You might like it (Predicted Rating: 2.80)
# The Shadow Throne (The Shadow Campaigns, #2) by Django Wexler: You might like it (Predicted Rating: 2.80)
# Ghost Particle: In Search of the Elusive and Mysterious Neutrino by Alan Chodos: You might like it (Predicted Rating: 2.80)
# Spy x Family, Vol. 1 by Tatsuya Endo: You might like it (Predicted Rating: 2.80)
# The Mote in God's Eye (Moties, #1) by Larry Niven: It might be okay (Predicted Rating: 2.79)
# 賭ケグルイ双 12 (Kakegurui Twin, #12) by Homura Kawamoto: It might be okay (Predicted Rating: 2.79)
# Superintelligence: Paths, Dangers, Strategies by Nick Bostrom: It might be okay (Predicted Rating: 2.79)
# Annihilation (Southern Reach, #1) by Jeff VanderMeer: It might be okay (Predicted Rating: 2.78)
# 賭ケグルイ双 13 (Kakegurui Twin, #13) by Homura Kawamoto: It might be okay (Predicted Rating: 2.78)
# Tinker, Tailor, Soldier, Spy (George Smiley, #5; Karla Trilogy, #1) by John Le Carré: It might be okay (Predicted Rating: 2.78)
# The End of October by Lawrence Wright: It might be okay (Predicted Rating: 2.78)
# The City of Ember (Book of Ember, #1) by Jeanne DuPrau: It might be okay (Predicted Rating: 2.77)
# Remote Control by Nnedi Okorafor: It might be okay (Predicted Rating: 2.77)
# Infinite Powers: The Story of Calculus - The Language of the Universe by Steven H. Strogatz: It might be okay (Predicted Rating: 2.77)
# Waylander (The Drenai Saga #3) by David Gemmell: It might be okay (Predicted Rating: 2.77)
# The Space Between Worlds (The Space Between Worlds, #1) by Micaiah Johnson: It might be okay (Predicted Rating: 2.76)
# Forging Hephaestus (Villains' Code, #1) by Drew  Hayes: It might be okay (Predicted Rating: 2.76)
# Captain Vorpatril's Alliance (Vorkosigan Saga, #15) by Lois McMaster Bujold: It might be okay (Predicted Rating: 2.75)
# Sixteen Ways to Defend a Walled City (The Siege, #1) by K.J. Parker: It might be okay (Predicted Rating: 2.75)
# The Book of Doors by Gareth  Brown: It might be okay (Predicted Rating: 2.75)
# The Devils (The Devils, #1) by Joe Abercrombie: It might be okay (Predicted Rating: 2.75)
# The Malevolent Seven (The Malevolent Seven, #1) by Sebastien de Castell: It might be okay (Predicted Rating: 2.74)
# The Way Spring Arrives and Other Stories by Yu Chen: It might be okay (Predicted Rating: 2.74)
# Shockwave (Star Kingdom, #1) by Lindsay Buroker: It might be okay (Predicted Rating: 2.74)
# They Come at Knight (Nena Knight, #2) by Yasmin Angoe: It might be okay (Predicted Rating: 2.73)
# Migrations by Charlotte McConaghy: It might be okay (Predicted Rating: 2.73)
# Postal, Vol. 1 by Matt Hawkins: It might be okay (Predicted Rating: 2.73)
# The Voice In All by Audrey Auden: It might be okay (Predicted Rating: 2.72)
# The Incendiaries by R.O. Kwon: It might be okay (Predicted Rating: 2.72)
# What Stalks the Deep (Sworn Soldier, #3) by T. Kingfisher: It might be okay (Predicted Rating: 2.72)
# The Deepest Map: The High-Stakes Race to Chart the World's Oceans by Laura Trethewey: It might be okay (Predicted Rating: 2.71)
# The Gunslinger (The Dark Tower, #1) by Stephen        King: It might be okay (Predicted Rating: 2.71)
# By the Grace of the Gods: Volume 1 (Light Novel) by Roy .: It might be okay (Predicted Rating: 2.71)
# The Fat Years by Chan Koonchung: It might be okay (Predicted Rating: 2.70)
# Stars’ Call (Battleship Chronicles, #1) by L. Eclaire: It might be okay (Predicted Rating: 2.70)
# A Play of Isaac (Joliffe the Player, #1) by Margaret Frazer: It might be okay (Predicted Rating: 2.69)
# The Girl Who Fell Beneath the Sea by Axie Oh: It might be okay (Predicted Rating: 2.69)
# Kings of the Wyld (The Band, #1) by Nicholas Eames: It might be okay (Predicted Rating: 2.68)
# A Hero Born (Legends of Condor Heroes #1) by Jin Yong: It might be okay (Predicted Rating: 2.67)
# The Nightingale Gallery (Sorrowful Mysteries of Brother Athelstan, #1) by Paul  Harding: It might be okay (Predicted Rating: 2.67)
# The City of Brass (The Daevabad Trilogy, #1) by S.A. Chakraborty: It might be okay (Predicted Rating: 2.67)
# Sweet Bean Paste by Durian Sukegawa: It might be okay (Predicted Rating: 2.67)
# 煉獄デッドロール 1 [Rengoku Deadroll 1] (Purgatory Dead Roll, #1) by Homura Kawamoto: It might be okay (Predicted Rating: 2.67)
# Untitled (The Singing Hills Cycle, #7) by Nghi Vo: It might be okay (Predicted Rating: 2.67)
# Untitled (The Singing Hills Cycle, #8) by Nghi Vo: It might be okay (Predicted Rating: 2.67)
# Rocannon’s World by Ursula K. Le Guin: It might be okay (Predicted Rating: 2.66)
# Masters of the Planet: The Search for Our Human Origins by Ian Tattersall: It might be okay (Predicted Rating: 2.66)
# The Lost Road and Other Writings (The History of Middle-Earth, #5) by J.R.R. Tolkien: It might be okay (Predicted Rating: 2.66)
# The Bear by Andrew Krivak: It might be okay (Predicted Rating: 2.65)
# The Dark Mirror (The Bridei Chronicles, #1) by Juliet Marillier: It might be okay (Predicted Rating: 2.65)
# A Sound of Thunder and Other Stories by Ray Bradbury: It might be okay (Predicted Rating: 2.65)
# The Eminence in Shadow (Light Novel), Volume 1 by Daisuke Aizawa: It might be okay (Predicted Rating: 2.63)
# The Unquiet Bones (Hugh de Singleton, Surgeon Chronicles #1) by Melvin R. Starr: It might be okay (Predicted Rating: 2.63)
# On Fragile Waves by E. Lily Yu: It might be okay (Predicted Rating: 2.63)
# The Shadow of the Gods (The Bloodsworn Saga, #1) by John Gwynne: It might be okay (Predicted Rating: 2.62)
# The Last Hour Between Worlds (The Echo Archives, #1) by Melissa Caruso: It might be okay (Predicted Rating: 2.61)
# Crashers (Crashers #1) by Dana Haynes: It might be okay (Predicted Rating: 2.61)
# The Heretics of De'Ath (The Chronicles of Brother Hermitage #1) by Howard of Warwick: It might be okay (Predicted Rating: 2.60)
# Silver Road (The Shifting Tides #2) by James   Maxwell: It might be okay (Predicted Rating: 2.59)
# Her Body and Other Parties: Stories by Carmen Maria Machado: It might be okay (Predicted Rating: 2.59)
# Lock In (Lock In, #1) by John Scalzi: It might be okay (Predicted Rating: 2.59)
# Fallen Into the Pit (Felse Investigations, #1) by Ellis Peters: It might be okay (Predicted Rating: 2.58)
# Dawn (Xenogenesis, #1) by Octavia E. Butler: It might be okay (Predicted Rating: 2.58)
# The Great Cleric (Light Novel): Volume 1 by Broccoli Lion: It might be okay (Predicted Rating: 2.58)
# Dissolution (Matthew Shardlake, #1) by C.J. Sansom: It might be okay (Predicted Rating: 2.57)
# A Wounded Realm (The Blood of Kings #2) by K.M. Ashman: It might be okay (Predicted Rating: 2.57)
# Foundryside (The Founders Trilogy, #1) by Robert Jackson Bennett: It might be okay (Predicted Rating: 2.56)
# The Echo Wife by Sarah Gailey: It might be okay (Predicted Rating: 2.56)
# Way Station by Clifford D. Simak: It might be okay (Predicted Rating: 2.55)
# Absolution by Murder (Sister Fidelma, #1) by Peter Tremayne: It might be okay (Predicted Rating: 2.55)
# One Day All This Will Be Yours by Adrian Tchaikovsky: It might be okay (Predicted Rating: 2.54)
# Annihilation (Mass Effect: Andromeda, #3) by Catherynne M. Valente: It might be okay (Predicted Rating: 2.54)
# Under Alien Skies: A Sightseer's Guide to the Universe by Philip Plait: It might be okay (Predicted Rating: 2.53)
# The Fall of Númenor: and Other Tales from the Second Age of Middle-earth by J.R.R. Tolkien: It might be okay (Predicted Rating: 2.53)
# The Hunger of the Gods (The Bloodsworn Saga, #2) by John Gwynne: It might be okay (Predicted Rating: 2.53)
# All the Troubles of the World by Isaac Asimov: It might be okay (Predicted Rating: 2.53)
# The Storm We Made by Vanessa  Chan: It might be okay (Predicted Rating: 2.53)
# Lovesickness by Junji Ito: It might be okay (Predicted Rating: 2.53)
# The Song of Achilles by Madeline Miller: It might be okay (Predicted Rating: 2.53)
# Exordia by Seth Dickinson: It might be okay (Predicted Rating: 2.52)
# To Sleep in a Sea of Stars (Fractalverse, #1) by Christopher Paolini: It might be okay (Predicted Rating: 2.52)
# Conclave by Robert   Harris: It might be okay (Predicted Rating: 2.52)
# Hell's Foundations Quiver (Safehold, #8) by David Weber: It might be okay (Predicted Rating: 2.52)
# The Black Company (The Chronicles of the Black Company, #1) by Glen Cook: It might be okay (Predicted Rating: 2.52)
# Vinland Saga, Tome 2 by Makoto Yukimura: It might be okay (Predicted Rating: 2.51)
# A Little Hatred (The Age of Madness, #1) by Joe Abercrombie: It might be okay (Predicted Rating: 2.51)
# Zone Fantôme, Tome 2 by Junji Ito: It might be okay (Predicted Rating: 2.51)
# Burning Brightly: 50 Years of Novacon by Ian Whates: It might be okay (Predicted Rating: 2.50)
# Wildwood Dancing (Wildwood, #1) by Juliet Marillier: It might be okay (Predicted Rating: 2.49)
# Infinity Gate (Pandominion, #1) by M.R. Carey: It might be okay (Predicted Rating: 2.49)
# What You Are Looking For Is in the Library by Michiko Aoyama: It might be okay (Predicted Rating: 2.49)
# Apothecary Melchior and the Mystery of St Olaf's Church by Indrek Hargla: It might be okay (Predicted Rating: 2.48)
# The Bones of the Old Ones (The Chronicles of Sword and Sand #2) by Howard Andrew Jones: It might be okay (Predicted Rating: 2.48)
# Murtagh (The Inheritance Cycle, #5) by Christopher Paolini: It might be okay (Predicted Rating: 2.47)
# Extracted (Extracted Trilogy, #1) by R.R. Haywood: It might be okay (Predicted Rating: 2.47)
# The Just City (Thessaly, #1) by Jo Walton: It might be okay (Predicted Rating: 2.47)
# Shadowfell (Shadowfell, #1) by Juliet Marillier: It might be okay (Predicted Rating: 2.47)
# The Broken Eye (Lightbringer, #3) by Brent Weeks: It might be okay (Predicted Rating: 2.47)
# Battle Cruiser (Lost Colonies Trilogy, #1) by B.V. Larson: It might be okay (Predicted Rating: 2.46)
# Translation State by Ann Leckie: It might be okay (Predicted Rating: 2.46)
# The Girl and the Stars (Book of the Ice, #1) by Mark  Lawrence: It might be okay (Predicted Rating: 2.46)
# A Thousand Devils (Max Heller, Dresden Detective #2) by Frank Goldammer: It might be okay (Predicted Rating: 2.46)
# The Water Outlaws by S.L. Huang: It might be okay (Predicted Rating: 2.45)
# The Rose Field (The Book of Dust #3) by Philip Pullman: It might be okay (Predicted Rating: 2.44)
# The Waters of Eternity (The Chronicles of Sword and Sand #1.5) by Howard Andrew Jones: It might be okay (Predicted Rating: 2.44)
# Red Storm Rising by Tom Clancy: It might be okay (Predicted Rating: 2.43)
# 14 (Threshold, #1) by Peter Clines: It might be okay (Predicted Rating: 2.42)
# Mickey7 (Mickey7 #1) by Edward Ashton: It might be okay (Predicted Rating: 2.41)
# When Breath Becomes Air by Paul Kalanithi: It might be okay (Predicted Rating: 2.41)
# A Cut for a Cut (Detective Kate Young, #2) by Carol Wyer: It might be okay (Predicted Rating: 2.41)
# Trigger Warning: Short Fictions and Disturbances by Neil Gaiman: It might be okay (Predicted Rating: 2.39)
# The God of the Woods by Liz    Moore: It might be okay (Predicted Rating: 2.39)
# Pathological by Jinkang Wang: It might be okay (Predicted Rating: 2.39)
# Lake of Souls: The Collected Short Fiction by Ann Leckie: It might be okay (Predicted Rating: 2.38)
# Winter of the World (The Century Trilogy #2) by Ken Follett: It might be okay (Predicted Rating: 2.37)
# Winter's Orbit (Winter's Orbit, #1) by Everina Maxwell: It might be okay (Predicted Rating: 2.37)
# Chaos: Making a New Science by James Gleick: It might be okay (Predicted Rating: 2.36)
# The Buried Giant by Kazuo Ishiguro: It might be okay (Predicted Rating: 2.36)
# We Have No Idea: A Guide to the Unknown Universe by Jorge Cham: It might be okay (Predicted Rating: 2.36)
# City of Illusions by Ursula K. Le Guin: It might be okay (Predicted Rating: 2.35)
# Killing Gravity (The Voidwitch Saga, #1) by Corey J. White: It might be okay (Predicted Rating: 2.35)
# The Heaven Tree (Heaven Tree, #1) by Edith Pargeter: It might be okay (Predicted Rating: 2.35)
# Imager (Imager Portfolio, #1) by L.E. Modesitt Jr.: It might be okay (Predicted Rating: 2.34)
# The Passage (The Passage, #1) by Justin Cronin: It might be okay (Predicted Rating: 2.34)
# Company (Beacon 23, #4) by Hugh Howey: It might be okay (Predicted Rating: 2.33)
# An Echo of Things to Come (The Licanius Trilogy, #2) by James  Islington: It might be okay (Predicted Rating: 2.33)
# Trinity (Wars of the Roses, #2) by Conn Iggulden: It might be okay (Predicted Rating: 2.33)
# Writings from Ancient Egypt by Anonymous: It might be okay (Predicted Rating: 2.33)
# The Final Flaw by Michael R. Sullivan: It might be okay (Predicted Rating: 2.33)
# The Tattered Banner (Society of the Sword, #1) by Duncan M. Hamilton: It might be okay (Predicted Rating: 2.33)
# Omega Rising (Omega Force, #1) by Joshua Dalzelle: It might be okay (Predicted Rating: 2.31)
# Radiance by Catherynne M. Valente: It might be okay (Predicted Rating: 2.31)
# I Have No Mouth & I Must Scream by Harlan Ellison: It might be okay (Predicted Rating: 2.30)
# The End of Men by Christina Sweeney-Baird: It might be okay (Predicted Rating: 2.29)
# The Collapsing Empire (The Interdependency, #1) by John Scalzi: It might be okay (Predicted Rating: 2.29)
# The Atrocity Archives (Laundry Files, #1) by Charles Stross: It might be okay (Predicted Rating: 2.28)
# The Shortest History of Europe by John Hirst: It might be okay (Predicted Rating: 2.28)
# Planet of Exile by Ursula K. Le Guin: It might be okay (Predicted Rating: 2.27)
# Service Model by Adrian Tchaikovsky: It might be okay (Predicted Rating: 2.27)
# The Shadow Land by Elizabeth Kostova: It might be okay (Predicted Rating: 2.27)
# Redemption (Infinity Blade, #2) by Brandon Sanderson: It might be okay (Predicted Rating: 2.27)
# Termination Shock by Neal Stephenson: It might be okay (Predicted Rating: 2.26)
# The Day of the Jackal by Frederick Forsyth: It might be okay (Predicted Rating: 2.26)
# Echo of Worlds (Pandominion, #2) by M.R. Carey: It might be okay (Predicted Rating: 2.25)
# Days at the Morisaki Bookshop (Days at the Morisaki Bookshop, #1) by Satoshi Yagisawa: It might be okay (Predicted Rating: 2.25)
# Machinehood by S.B. Divya: It might be okay (Predicted Rating: 2.24)
# The Relentless Legion (The Divide #3) by J.S. Dewes: It might be okay (Predicted Rating: 2.24)
# Homeland (Forgotten Realms: The Dark Elf Trilogy, #1; Legend of Drizzt, #1) by R.A. Salvatore: It might be okay (Predicted Rating: 2.24)
# Head in the Sand (DI Nick Dixon, #2) by Damien Boyd: It might be okay (Predicted Rating: 2.23)
# The Confusion (The Baroque Cycle, #2) by Neal Stephenson: It might be okay (Predicted Rating: 2.23)
# Beautyland by Marie-Helene Bertino: It might be okay (Predicted Rating: 2.22)
# The School for Good Mothers by Jessamine Chan: It might be okay (Predicted Rating: 2.21)
# The Icepick Surgeon: Murder, Fraud, Sabotage, Piracy, and Other Dastardly Deeds Perpetrated in the Name of Science by Sam Kean: It might be okay (Predicted Rating: 2.18)
# The First Fifteen Lives of Harry August by Claire North: It might be okay (Predicted Rating: 2.18)
# Legion and The Emperor's Soul by Brandon Sanderson: It might be okay (Predicted Rating: 2.17)
# Unexpected Rain (The Dome Trilogy, Book 1) by Jason W. LaPier: It might be okay (Predicted Rating: 2.16)
# A Memory Called Empire (Teixcalaan, #1) by Arkady Martine: It might be okay (Predicted Rating: 2.16)
# The Tainted Cup (Shadow of the Leviathan, #1) by Robert Jackson Bennett: It might be okay (Predicted Rating: 2.15)
# Overlord, Volume 1: The Undead King (Overlord, #1) by Kugane Maruyama: It might be okay (Predicted Rating: 2.14)
# The Warm Hands of Ghosts by Katherine Arden: It might be okay (Predicted Rating: 2.13)
# The Book of the New Sun by Gene Wolfe: It might be okay (Predicted Rating: 2.13)
# Light of the Jedi (Star Wars: The High Republic) by Charles Soule: It might be okay (Predicted Rating: 2.12)
# Outlaw (On the Bones of Gods #2) by K. Eason: It might be okay (Predicted Rating: 2.12)
# Dauntless (The Lost Fleet, #1) by Jack Campbell: It might be okay (Predicted Rating: 2.12)
# Usurpation (Semiosis, #3) by Sue Burke: It might be okay (Predicted Rating: 2.11)
# Victorious (Villains, #3) by V.E. Schwab: It might be okay (Predicted Rating: 2.11)
# Dunstan by Conn Iggulden: It might be okay (Predicted Rating: 2.11)
# Grunt: The Curious Science of Humans at War by Mary Roach: It might be okay (Predicted Rating: 2.08)
# Martyr! by Kaveh Akbar: It might be okay (Predicted Rating: 2.06)
# Not Till We Are Lost (Bobiverse, #5) by Dennis E. Taylor: It might be okay (Predicted Rating: 2.06)
# Shantaram by Gregory David Roberts: It might be okay (Predicted Rating: 2.05)
# Jorundyr's Path (Wolf of the North, #2) by Duncan M. Hamilton: It might be okay (Predicted Rating: 2.03)
# Villain (Hench, #2) by Natalie Zina Walschots: It might be okay (Predicted Rating: 2.01)
# The Windup Girl by Paolo Bacigalupi: You probably won't like it (Predicted Rating: 1.95)
# Wolf Hall (Thomas Cromwell, #1) by Hilary Mantel: You probably won't like it (Predicted Rating: 1.94)
# Hammajang Luck by Makana Yamamoto: You probably won't like it (Predicted Rating: 1.86)
# A Master of Djinn (Dead Djinn Universe, #1) by P. Djèlí Clark: You probably won't like it (Predicted Rating: 1.75)
# The Iron Ship (The Gates of the World, #1) by K.M. McKinley: You probably won't like it (Predicted Rating: 1.48)
# Untitled (The Wakening, #2) by Jonathan Renshaw: You probably won't like it (Predicted Rating: 1.43)

# %%
def predict_book_rating(title, author, year_published, num_pages, genres):
    book_features = pd.DataFrame(index=[0])
    
    # Handle unknown authors by trying to transform, falling back to 'Unknown Author'
    try:
        book_features['Author'] = author_encoder.transform([author])
    except ValueError:
        book_features['Author'] = author_encoder.transform(['Unknown Author'])
    
    # Rest of the function remains the same
    book_features['Year Published'] = year_published
    book_features['Number of Pages'] = num_pages
    
    known_genres = list(set(genres) & set(mlb.classes_))
    if not known_genres:
        known_genres = [''] 

    genre_features = pd.DataFrame(
        mlb.transform([known_genres]), 
        columns=mlb.classes_,
        index=[0]
    )
    
    book_features = pd.concat([book_features, genre_features], axis=1)
    predicted_rating = random_forest_model.predict(book_features)[0]
    
    return {
        'Title': title,
        'Predicted Rating': predicted_rating,
        'Rating Sentence': "You might like it" if predicted_rating >= 2.8 
                         else ("It might be okay" if predicted_rating >= 2.0 
                         else "You probably won't like it")
    }

# Example usage
test_books = [
    {
        'title': 'Project Hail Mary',
        'author': 'Andy Weir',
        'year': 2021,
        'pages': 496,
        'genres': ['science-fiction', 'fiction']
    },
    {
        'title': '1984',
        'author': 'James Jameson',
        'year': 2022,
        'pages': 328,
        'genres': ['fiction', 'classics', 'dystopian', 'cozy', 'science-fiction']
    }
]

# Get predictions for test books
for book in test_books:
    result = predict_book_rating(
        book['title'],
        book['author'],
        book['year'],
        book['pages'],
        book['genres']
    )
    print(f"\n{result['Title']}:")
    print(f"Predicted Rating: {result['Predicted Rating']:.2f}")
    print(f"Recommendation: {result['Rating Sentence']}")
# Out:
# Project Hail Mary:
# Predicted Rating: 3.65
# Recommendation: You might like it
#
# 1984:
# Predicted Rating: 2.78
# Recommendation: It might be okay

# %%
import joblib

model_data = {
    'model': random_forest_model,
    'author_encoder': author_encoder,
    'genre_encoder': mlb
}

# Save with highest protocol and compressed numpy arrays
joblib.dump(model_data, 'goodreads_model.joblib', 
           compress=('gzip', 3), 
           protocol=4)
# Out:
# ['goodreads_model.joblib']
